# %% [markdown]
# # 文本处理
#
# ### 官方处理流程
# ```sh
# python2 ./data/tools.py -m filter -s ./data/News_info_train.txt -t ./clean_data/News_info_train_filter.txt
# python2 ./data/tools.py -m filter -s ./data/News_info_unlabel.txt -t ./clean_data/News_info_unlabel_filter.txt
# python2 ./data/tools.py -m filter -s ./data/News_info_validate.txt -t ./clean_data/News_info_validate_filter.txt
# python2 ./data/tools.py -m filter -s ./data/News_info_label_train_example100.txt -t ./clean_data/News_info_label_train_example100_filter.txt
# ```
#
# ### 自定义处理流程

# %%
import jieba
import pandas as pd
from html.parser import HTMLParser

def is_uchar(uchar):
    """判断一个unicode是否是汉字"""
    if uchar >= u'\u4e00' and uchar<=u'\u9fa5':
            return True
    """判断一个unicode是否是数字"""
    if uchar >= u'\u0030' and uchar<=u'\u0039':
            return True        
    """判断一个unicode是否是英文字母"""
    if (uchar >= u'\u0041' and uchar<=u'\u005a') or (uchar >= u'\u0061' and uchar<=u'\u007a'):
            return True
    if uchar in ('-',',','，','。','.','<','>','?'):
            return True
    return False

def str_filter(s):
    ret=''
    for i in s:
        ret += i if is_uchar(i) else ' '
    return ret

class MyHTMLParser(HTMLParser):
    def __init__(self):
        self.dom_stack=[]
        self.text=''
        super(MyHTMLParser,self).__init__()
    def handle_starttag(self, tag, attrs):
        if 'br' == tag:
            self.text +=' CONTROL_BREAK '
        elif 'p' == tag:
            self.text +=' CONTROL_NEWP '
        elif 'span' == tag:
            self.text +=' CONTROL_SPAN_START '
        elif 'strong' == tag:
            self.text +=' CONTROL_STRONG_START '
        self.dom_stack.append(tag)

    def handle_endtag(self, tag):
        if 'span' == tag:
            self.text +=' CONTROL_SPAN_END '
        elif 'strong' == tag:
            self.text +=' CONTROL_STRONG_END '
        self.dom_stack.pop()
        
    def current_dom(self):
        return self.dom_stack[-1] if len(self.dom_stack)>0 else 'empty'
    
    def clear(self):
        self.dom_stack=[]
        self.text=''
    
    def handle_data(self, data):
        data=data.strip()
        data=str_filter(data)
        data=' '.join(jieba.cut(data))
        current_dom = self.current_dom()
        if current_dom == 'title':
            self.title = data
        elif current_dom == 'p':
            self.text += ' CONTROL_EMPTYP ' if 0 == len(data) else ' %s '%(data)
        elif current_dom == 'span':
            self.text += ' CONTROL_EMPTYSPAN ' if 0 == len(data) else ' %s '%(data)
        elif current_dom == 'strong':
            self.text += ' CONTROL_EMPTYSTRONG ' if 0 == len(data) else ' %s '%(data)
        elif current_dom == 'html':
            self.text += '  ' if 0 == len(data) else ' CONTROL_NONEMPTYHTMLSTART %s CONTROL_NONEMPTY_HTML_END '%(data)
        elif current_dom == 'body':
            self.text += '  ' if 0 == len(data) else ' CONTROL_NONEMPTY_BODY_START %s CONTROL_NONEMPTY_BODY_END '%(data)
        elif current_dom == 'h1':
            self.text += ' CONTROL_NONEMPTY_H1_BEGIN %s CONTROL_NONEMPTY_H1_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_H1 '
        elif current_dom == 'h2':
            self.text += ' CONTROL_NONEMPTY_H2_BEGIN %s CONTROL_NONEMPTY_H2_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_H2 '
        elif current_dom == 'h3':
            self.text += ' CONTROL_NONEMPTY_H3_BEGIN %s CONTROL_NONEMPTY_H3_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_H3 '
        elif current_dom == 'h4':
            self.text += ' CONTROL_NONEMPTY_H4_BEGIN %s CONTROL_NONEMPTY_H4_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_H4 '
        elif current_dom == 'h5':
            self.text += ' CONTROL_NONEMPTY_H5_BEGIN %s CONTROL_NONEMPTY_H5_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_H5 '
        elif current_dom == 'br':
            self.text += ' CONTROL_NONEMPTY_BR_BEGIN %s CONTROL_NONEMPTY_BR_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_BR '
        elif current_dom == 'tr':
            self.text += ' CONTROL_NONEMPTY_TR_BEGIN %s CONTROL_NONEMPTY_TR_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_TR '
        elif current_dom == 'td':
            self.text += ' CONTROL_NONEMPTY_TD_BEGIN %s CONTROL_NONEMPTY_TD_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_TD '
        elif current_dom == 'th':
            self.text += ' CONTROL_NONEMPTY_TH_BEGIN %s CONTROL_NONEMPTY_TH_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_TH '
        elif current_dom == 'ul':
            self.text += ' CONTROL_NONEMPTY_UL_BEGIN %s CONTROL_NONEMPTY_UL_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_UL '
        elif current_dom == 'li':
            self.text += ' CONTROL_NONEMPTY_LI_BEGIN %s CONTROL_NONEMPTY_LI_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_LI '
        elif current_dom == 'ol':
            self.text += ' CONTROL_NONEMPTY_OL_BEGIN %s CONTROL_NONEMPTY_OL_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_OL '
        elif current_dom == 'blockquote':
            self.text += ' CONTROL_NONEMPTY_BLOCK_QUOTE_BEGIN %s CONTROL_NONEMPTY_BLOCK_QUOTE_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_BLOCK_QUOTE '
        elif current_dom == 'i':
            self.text += ' CONTROL_NONEMPTY_I_BEGIN %s CONTROL_NONEMPTY_I_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_I '
        elif current_dom == 'b':
            self.text += ' CONTROL_NONEMPTY_B_BEGIN %s CONTROL_NONEMPTY_B_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_B '
        elif current_dom == 'how':
            self.text += ' CONTROL_NONEMPTY_HOW_BEGIN %s CONTROL_NONEMPTY_HOW_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_HOW '
        elif current_dom == 'le':
            self.text += ' CONTROL_NONEMPTY_LE_BEGIN %s CONTROL_NONEMPTY_LE_END '%(data) if len(data) > 0 else ' CONTROL_EMPTY_LE '
        elif current_dom in ['img', 'a']:
            self.text += ' CONTROL_UNTRACED_ITEM '
        else:
            print("In dom:%s, Skip string: \"%s\""%(current_dom, data))
    
    def get_text(self):
        return self.text
    
    def get_title(self):
        return self.title

# %% [markdown]
# # 数据预处理
#
# - 解析HTML
# - 过滤无效字符
# - 生成文本
# - 拼接数据

# %%
news_info_train = pd.read_csv('./data/News_info_train.txt',names=['id', 'html', 'Pics'], sep='\t', index_col='id')
news_pic_label_train=pd.read_csv('./data/News_pic_label_train.txt',names=['id', 'label', 'target_pic', 'target_text'], sep='\t', index_col='id')
news_info_train['title']=''
news_info_train['text']=''
def dom_apply(row):
    parser.clear()
    parser.feed('<html>%s</html>'%str.strip(row['html']))
    row['title']=parser.get_title()
    row['text']=parser.get_text()
    return row
parser = MyHTMLParser()
news_info_train=news_info_train.apply(dom_apply, axis=1)
parser.close()
news_info_train.drop('html',axis=1,inplace=True)
news_info_train['Pics'] = news_info_train['Pics'].fillna('')
news_pic_label_train.loc[:,('target_pic', 'target_text')]=news_pic_label_train.loc[:,('target_pic', 'target_text')].fillna('')
news_pic_label_train['target_text']=news_pic_label_train['target_text'].apply(lambda x:' '.join(jieba.cut(x)))
news_info_train=news_info_train.join(news_pic_label_train)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.688 seconds.
# Prefix dict has been built succesfully.

# %%
news_info_train.to_hdf('./clean_data/data.hdf5','news_info_train')
news_info_train
# Out:
#                                                        Pics  \
# id
# D0000001  P0000001.JPEG;P0000002.JPEG;P0000003.JPEG;P000...
# D0000002  P0000016.JPEG;P0000017.JPEG;P0000018.JPEG;P000...
# D0000003  P0000025.JPEG;P0000026.JPEG;P0000027.JPEG;P000...
# D0000004  P0000032.JPEG;P0000033.JPEG;P0000034.JPEG;P000...
# D0000005
# D0000006                        P0000039.JPEG;P0000040.JPEG
# D0000007
# D0000008  P0000041.JPEG;P0000042.JPEG;P0000043.JPEG;P000...
# D0000009
# D0000010          P0000052.JPEG;P0000053.JPEG;P0000054.JPEG
# D0000011
# D0000012                         P0000055.JPEG;P0000056.PNG
# D0000013  P0000057.PNG;P0000058.JPEG;P0000059.JPEG;P0000...
# D0000014  P0000072.GIF;P0000073.JPEG;P0000074.JPEG;P0000...
# D0000015                         P0000084.PNG;P0000085.JPEG
# D0000016
# D0000017                                      P0000086.JPEG
# D0000018  P0000087.JPEG;P0000088.JPEG;P0000089.JPEG;P000...
# D0000019
# D0000020  P0000097.GIF;P0000098.JPEG;P0000099.JPEG;P0000...
# D0000021  P0000128.GIF;P0000129.GIF;P0000130.GIF;P000013...
# D0000022          P0000137.JPEG;P0000138.JPEG;P0000139.JPEG
# D0000023                          P0000140.PNG;P0000141.PNG
# D0000024  P0000142.JPEG;P0000143.JPEG;P0000144.JPEG;P000...
# D0000025  P0000146.JPEG;P0000147.JPEG;P0000148.JPEG;P000...
# D0000026
# D0000027
# D0000028  P0000154.JPEG;P0000155.JPEG;P0000156.JPEG;P000...
# D0000029
# D0000030
# ...                                                     ...
# D0048451
# D0048452          P0351509.JPEG;P0351510.JPEG;P0351511.JPEG
# D0048453
# D0048454  P0351512.JPEG;P0351513.JPEG;P0351514.JPEG;P035...
# D0048455  P0351526.JPEG;P0351527.JPEG;P0351528.JPEG;P035...
# D0048456  P0351537.JPEG;P0351538.JPEG;P0351539.JPEG;P035...
# D0048457
# D0048458  P0351556.JPEG;P0351557.JPEG;P0351558.JPEG;P035...
# D0048459  P0351562.JPEG;P0351563.JPEG;P0351564.JPEG;P035...
# D0048460  P0351568.GIF;P0351569.JPEG;P0351570.JPEG;P0351...
# D0048461  P0351573.JPEG;P0351574.JPEG;P0351575.JPEG;P035...
# D0048462                                      P0351591.JPEG
# D0048463
# D0048464  P0351592.JPEG;P0351593.JPEG;P0351594.JPEG;P035...
# D0048465          P0351598.JPEG;P0351599.JPEG;P0351600.JPEG
# D0048466  P0351601.JPEG;P0351602.JPEG;P0351603.JPEG;P035...
# D0048467  P0351606.JPEG;P0351607.JPEG;P0351608.JPEG;P035...
# D0048468  P0351612.JPEG;P0351613.JPEG;P0351614.JPEG;P035...
# D0048469                                      P0351655.JPEG
# D0048470
# D0048471  P0351656.JPEG;P0351657.JPEG;P0351658.JPEG;P035...
# D0048472  P0351661.JPEG;P0351662.JPEG;P0351663.JPEG;P035...
# D0048473
# D0048474  P0351668.JPEG;P0351669.JPEG;P0351670.JPEG;P035...
# D0048475  P0351677.JPEG;P0351678.JPEG;P0351679.JPEG;P035...
# D0048476                                      P0351681.JPEG
# D0048477  P0351682.JPEG;P0351683.PNG;P0351684.PNG;P03516...
# D0048478           P0351714.JPEG;P0351715.JPEG;P0351716.PNG
# D0048479  P0351717.GIF;P0351718.GIF;P0351719.JPEG;P03517...
# D0048480  P0351725.JPEG;P0351726.JPEG;P0351727.JPEG;P035...
#
#                                                       title  \
# id
# D0000001                       惠尔 新品       冷色 系 实木 多层 地板 系列
# D0000002         82 周年 庆       收到 八方 来 贺 之 第一波   女士 专场 福利
# D0000003             黄河 片区 压轴 大戏 , 美林 康城 铂悦府 1 月 13 日 优惠 升级
# D0000004  早安       世界 上 所有 的 惊喜 与 好运 , 都 是 你 积累 的 人品 与 善良 。
# D0000005              中文 到底 有 多难 ? 为教 马克 龙说 这句 话   翻译 差点 崩溃
# D0000006             空调 送风 千篇一律   卡萨帝 CES 展示 1 台 空调 吹 多种 温度
# D0000007                                   手机 辐射 美女 竟然 这么 用
# D0000008           68 岁 老人 走路 送 快递 7 年   为 还 老伴 治病 欠 的 80 万
# D0000009                                      师哥 送 小妖女 情人 泪
# D0000010                古茗 奶茶 加盟 小 本 创业 的 好 选择 , 加盟 利润 空间 大
# D0000011                           1 - 5 大脑 焦油 坑 到底 有 多 坑 企
# D0000012         奇迹 暖 暖 凝砂 套装 星夜 预言家 的 展示 m . aituiyx . com
# D0000013            开 房车 旅行 真的 好 吗 ?   副作用   惊人 为啥 还 这么 火
# D0000014  断崖 式 降温 又 来 了   这 款 冬日 限量 的 滋润 修护 霜 , 再 不 买 就要 断货
# D0000015                再 牛 的 iPhone   7 , 也 拍 不出 我 的 高鼻梁
# D0000016                          广东 佛山   地铁 施工 路段 发生 地面 塌陷
# D0000017         龙头 房企   开门红     碧桂园 万科 恒大首 月 销售额 均 破 600 亿
# D0000018                      淑芳 家纺   冬天 盖 蚕丝被 , 会 有 啥 后果 ?
# D0000019                                 受伤 退役 运动员 变美 重拾 自信
# D0000020                    饱腹 饼干 里 的 老 司机 , 高颜值 超 美味 低热量
# D0000021                  当 朗读 亭 遇上 厦图 , 你 也 可以 是 最美 的 朗 读者
# D0000022  LOL   比   秒表   更 恶心 的 天赋 , 它 的 存在 已经 让 职业 赛场 得...
# D0000023      阴阳师 青行 灯 新 皮肤 青灯 夜话 立 绘图 鉴   青行 灯 青灯 夜话 皮肤 介绍
# D0000024                     12 月 20 日 各地 红薯 山楂 花生 瓜子 批发 信息
# D0000025                        冬至 养生 要 趁早   吃 什么 素食 能 养生
# D0000026                     不 知道   街巷 长   这件 事 你 就 out 了
# D0000027              视频   河北 华夏 1 - 2 基辅 迪 那 摩 , 埃尔纳 内斯 破门
# D0000028           这三大 星座 在 感情 里 只会 索取 , 不会 付出 , 真是 没 谁 了
# D0000029             物流 教育   人员 结构 失衡 , 职业 高校 探索 物流 人才培养 模式
# D0000030              睿 奇 天骄   陪伴 就是 最好 的 孝道 , 你 回家 看过 父母 吗
# ...                                                     ...
# D0048451                      米其林 级别 甜品 诞生   霆 锋 萧敬腾 音乐 趴开餐
# D0048452              瘦身 篇       柠檬 片 泡水 的 功效   帮 你 甩掉 肥肉 肉
# D0048453  谢娜 张杰   -   黄晓明 首次 坦白 为何 会 娶 烟瘾 这么 重 的 baby   ...
# D0048454            年货 大团购     山哥 海鲜 礼盒   300 多 竟然 还有 大龙虾
# D0048455        JESSIE 冬日 里 最美 的 色彩 ,   优雅 , 简单 , 再 优雅 简单
# D0048456                       千万别 穿 这样 颜色 的 衣服 , 实在 太美 了
# D0048457            山西 市场主体 活力 有效 激活 地税 系统 纳税户 5 年 增长 近 1 倍
# D0048458                       创业 动态   共享 式 净水器 , 每天 只要 2 元
# D0048459                                刊物     永嘉 文艺   征稿启事
# D0048460                懂 茶妹 说 茶   同样 是 茶 , 为什么 会 有 百般 风味 ?
# D0048461    正阳县 彭桥 乡 大 刘村 红旗 飘扬   高挂 大 红灯笼   人们 洋溢着 喜悦 的 笑容
# D0048462                               死刑   杭州 保姆 纵火案 一审 宣判
# D0048463                                      久违 的 新股 双双 到来
# D0048464                          精彩表演 送 下乡 , 让 这个 小山村 沸腾 了
# D0048465                    年底 , 又 一起 跳河 事件 , 生命 怎可 如此 轻视 ?
# D0048466                             滑雪 价格 丨 绕行 线路 丨 直通车 信息
# D0048467    疯传   永居 8 年 才能 入籍 ?   还要 雅思 4 个 6 ? 最新 改革 议案...
# D0048468  一年 里 囤 内衣 最 划算 的 时候 , 维密 比海 淘 便宜 , 香水   身体 乳 也...
# D0048469                    晚 19 点       国 考考试 解析   快来 快来
# D0048470                        青年 首次 置业 精选   不 限购 公寓 拎包 入住
# D0048471                        新 的 冒险   手游   发条 英雄   即将 开测
# D0048472                             何 凯文 冲刺 绝对 必考 100 词 笔记
# D0048473              羊价 上涨 ?       2018 年 1 月 7 日 国内 最新 羊价
# D0048474  松江       泡温泉   采摘 水果   赏花 垂钓 ..... 约 你 来 新 浜 ,...
# D0048475           海外 备受 追捧 的 智能 微型 投影仪 , 上线 京东 众筹 只 需 19 元
# D0048476                   便携式 汽车 轮 重衡 种类 繁多 该 如何 选择 选购   ?
# D0048477                     东莞 14 家 培训 机构 2017 年 年检 不 合格
# D0048478     2018 年 会计 考试 日历 新鲜出炉   2018 年 备考 之旅 , 该 启程 啦
# D0048479                   颜值 更 高   气质 更佳 的 田林 社区 靠 什么 打造 ?
# D0048480                  合格 的 儿童乐园 店长 , 是 这样 做 客户资源 维护 的
#
#                                                        text  label  \
# id
# D0000001     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      0
# D0000002     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      2
# D0000003     CONTROL_NEWP  自 2017 年  CONTROL_STRONG_STAR...      2
# D0000004     CONTROL_NEWP  CONTROL_EMPTYP  CONTROL_STRON...      0
# D0000005   CONTROL_NONEMPTYHTMLSTART 中文 到底 有 多难   为教 马克 ...      0
# D0000006     CONTROL_NEWP  智慧 家庭 将 成为 2018 家居 家电 领域 新风 口...      0
# D0000007   CONTROL_NONEMPTYHTMLSTART 手机 辐射 美女 竟然 这么 用 CO...      0
# D0000008     CONTROL_NEWP  来源   看看 新闻    CONTROL_BREAK  ...      0
# D0000009   CONTROL_NONEMPTYHTMLSTART 艳骨 ， 师哥 送 小妖女 情人 泪 ...      0
# D0000010     CONTROL_NEWP  CONTROL_EMPTYP  CONTROL_SPAN_...      2
# D0000011   CONTROL_NONEMPTYHTMLSTART 1 - 5 大脑 焦油 坑 到底 有 ...      0
# D0000012     CONTROL_NEWP  奇迹 暖 暖 开启 了 新 的 凝砂 套装 , 想必 大家...      0
# D0000013     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      1
# D0000014     CONTROL_NEWP  CONTROL_EMPTYP  CONTROL_SPAN_...      0
# D0000015     CONTROL_NEWP  iPhone7   Plus   的 双 摄像头 , 也 ...      0
# D0000016   CONTROL_NONEMPTYHTMLSTART   江西 卫视     晨光 新视界 ...      0
# D0000017     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      0
# D0000018     CONTROL_NEWP  CONTROL_SPAN_START  CONTROL_S...      0
# D0000019   CONTROL_NONEMPTYHTMLSTART 受伤 退役 运动员 变美 重拾 自信 ...      2
# D0000020     CONTROL_NEWP       CONTROL_BREAK  CONTROL_N...      1
# D0000021     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      0
# D0000022     CONTROL_NEWP  在 最近 的 英雄 联盟 LPL 和 LCK 比赛 中 ,...      0
# D0000023     CONTROL_NEWP  阴阳师 体验 服 上线 了 青行 灯 的 最新 皮肤   ...      0
# D0000024     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      0
# D0000025     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      1
# D0000026     CONTROL_NEWP  CONTROL_EMPTYP  CONTROL_STRON...      0
# D0000027     CONTROL_NEWP  北京 时间 今天 凌晨 , 正在 马 贝拉 冬训 的 河北...      0
# D0000028     CONTROL_NEWP  你 在 感情 里 也 一定 遇到 过 这样 的 人 , 不...      0
# D0000029     CONTROL_NEWP  CONTROL_STRONG_START  CONTROL...      0
# D0000030     CONTROL_NEWP    CONTROL_BREAK  CONTROL_NEWP...      0
# ...                                                     ...    ...
# D0048451   CONTROL_NONEMPTYHTMLSTART 米其林 级别 甜品 诞生   霆 锋 ...      0
# D0048452     CONTROL_NEWP  柠檬 美容 是 大家 都 知道 的 , 但是 您 知道 柠...      0
# D0048453   CONTROL_NONEMPTYHTMLSTART 谢娜 张杰   -   黄晓明 首次 ...      0
# D0048454     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      2
# D0048455     CONTROL_NEWP  CONTROL_SPAN_START  岁月 在 大 地上...      0
# D0048456     CONTROL_NEWP  CONTROL_EMPTYP  CONTROL_SPAN_...      2
# D0048457     CONTROL_NEWP  纳税户 5 年 增长 近 1 倍 , 新兴产业 税收 同比...      0
# D0048458     CONTROL_NEWP  1    CONTROL_BREAK  CONTROL_N...      2
# D0048459     CONTROL_NEWP  CONTROL_EMPTYP  CONTROL_SPAN_...      1
# D0048460     CONTROL_NEWP  绿茶 清鲜   乌龙茶 甘香   红茶 甜蜜 , 同样 是...      1
# D0048461     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      1
# D0048462     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      0
# D0048463     CONTROL_NEWP  jinrixingu    CONTROL_BREAK  ...      0
# D0048464     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      0
# D0048465     CONTROL_NEWP  2 月 8 号 上午 , 在 安徽 池州 清溪 河 , 又...      0
# D0048466     CONTROL_NEWP  导   读    CONTROL_BREAK  CONTR...      2
# D0048467     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      1
# D0048468     CONTROL_NEWP  CONTROL_EMPTYP  CONTROL_SPAN_...      0
# D0048469     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      2
# D0048470     CONTROL_NEWP  2017 年 是 楼市 风起云涌 的 一年 , 限购 限售...      0
# D0048471     CONTROL_NEWP    发条 英雄     原名     无尽 的 使命   ...      0
# D0048472     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      0
# D0048473     CONTROL_NEWP  最近 牛羊肉 价格 都 出现 了 上涨 , 其中 羊肉 的...      0
# D0048474   CONTROL_NONEMPTYHTMLSTART 新 浜 ， 地处 黄浦江 上游 ， 水...      2
# D0048475     CONTROL_NEWP  提到 Anker 这个 品牌 , 很多 人 第一 时间 想...      2
# D0048476     CONTROL_NEWP  便携式 汽车 轮 重衡 种类 繁多 该 如何 选购 ? 便...      2
# D0048477     CONTROL_NEWP  CONTROL_EMPTYP  CONTROL_SPAN_...      0
# D0048478     CONTROL_NEWP    CONTROL_BREAK  CONTROL_NEWP...      0
# D0048479     CONTROL_NEWP  CONTROL_EMPTYP    CONTROL_BRE...      0
# D0048480     CONTROL_NEWP  客户 维护 的 核心 是 让 客户 不但 在 玩耍 的 过...      1
#
#                                                  target_pic  \
# id
# D0000001
# D0000002
# D0000003
# D0000004
# D0000005
# D0000006
# D0000007
# D0000008
# D0000009
# D0000010
# D0000011
# D0000012
# D0000013
# D0000014
# D0000015
# D0000016
# D0000017
# D0000018
# D0000019
# D0000020  P0000123.JPEG;P0000124.JPEG;P0000125.JPEG;P000...
# D0000021
# D0000022
# D0000023
# D0000024
# D0000025                         P0000152.GIF;P0000153.JPEG
# D0000026
# D0000027
# D0000028
# D0000029
# D0000030
# ...                                                     ...
# D0048451
# D0048452
# D0048453
# D0048454
# D0048455
# D0048456
# D0048457
# D0048458
# D0048459
# D0048460
# D0048461                        P0351573.JPEG;P0351590.JPEG
# D0048462
# D0048463
# D0048464
# D0048465
# D0048466
# D0048467                                      P0351606.JPEG
# D0048468
# D0048469
# D0048470
# D0048471
# D0048472
# D0048473
# D0048474
# D0048475
# D0048476
# D0048477
# D0048478
# D0048479
# D0048480
#
#                                                 target_text
# id
# D0000001
# D0000002
# D0000003
# D0000004
# D0000005
# D0000006
# D0000007
# D0000008
# D0000009
# D0000010
# D0000011
# D0000012
# D0000013                                              关注 我们
# D0000014
# D0000015
# D0000016
# D0000017
# D0000018
# D0000019
# D0000020  我们 直接 从 英国 采购 , 从 源头 把关 , 面对 网上 各种 酸奶 饼干 , 请 大...
# D0000021
# D0000022
# D0000023
# D0000024
# D0000025
# D0000026
# D0000027
# D0000028
# D0000029
# D0000030
# ...                                                     ...
# D0048451
# D0048452
# D0048453
# D0048454
# D0048455
# D0048456
# D0048457
# D0048458
# D0048459                                       by :   永嘉 文艺
# D0048460  【 此 文章 为 英德 姐妹 茶庄 的 懂 茶妹 整理 发布 , 转载 请 说明 , 特此 ...
# D0048461
# D0048462
# D0048463
# D0048464
# D0048465
# D0048466
# D0048467  本文 内容 为 新石器 留学 移民 原创 撰写 , 编辑 和 校译 , 版权所有 ! 全部 ...
# D0048468
# D0048469
# D0048470
# D0048471
# D0048472
# D0048473
# D0048474
# D0048475
# D0048476
# D0048477
# D0048478
# D0048479
# D0048480  淘气堡 儿童乐园 专用 彩绘 地垫 适用 于 儿童 职业 体验 馆 、 亲子 游乐园 、 儿...
#
# [48480 rows x 6 columns]

# %% [markdown]
# ### 生成语料库
#
# 从label和unlabel的数据中抽取所有文本

# %%
news_info_unlabeled = pd.read_csv('./data/News_info_unlabel.txt',names=['id', 'html', 'Pics'], sep='\t', index_col='id')
news_info_unlabeled['title']=''
news_info_unlabeled['text']=''
def dom_apply(row):
    parser.clear()
    parser.feed('<html>%s</html>'%str.strip(row['html']))
    row['title']=parser.get_title()
    row['text']=parser.get_text()
    return row
parser = MyHTMLParser()
news_info_unlabeled=news_info_unlabeled.apply(dom_apply, axis=1)
parser.close()
news_info_unlabeled.drop('html',axis=1,inplace=True)
news_info_unlabeled['Pics'] = news_info_unlabeled['Pics'].fillna('')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-73642d29f4f0> in <module>()
#       9     return row
#      10 parser = MyHTMLParser()
# ---> 11 news_info_unlabeled=news_info_unlabeled.apply(dom_apply, axis=1)
#      12 parser.close()
#      13 news_info_unlabeled.drop('html',axis=1,inplace=True)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
#    4360             except Exception as e:
#
# <ipython-input-6-73642d29f4f0> in dom_apply(row)
#       4 def dom_apply(row):
#       5     parser.clear()
# ----> 6     parser.feed('<html>%s</html>'%str.strip(row['html']))
#       7     row['title']=parser.get_title()
#       8     row['text']=parser.get_text()
#
# ~/anaconda3/lib/python3.6/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~/anaconda3/lib/python3.6/html/parser.py in goahead(self, end)
#     161             if i < j:
#     162                 if self.convert_charrefs and not self.cdata_elem:
# --> 163                     self.handle_data(unescape(rawdata[i:j]))
#     164                 else:
#     165                     self.handle_data(rawdata[i:j])
#
# <ipython-input-1-8b39c3f5e320> in handle_data(self, data)
#     107             self.text += ' CONTROL_UNTRACED_ITEM '
#     108         else:
# --> 109             print("In dom:%s, Skip string: \"%d\""%(current_dom, data))
#     110
#     111     def get_text(self):
#
# TypeError: ('%d format: a number is required, not str', 'occurred at index D0081936')
